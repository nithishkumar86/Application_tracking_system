# %%
from pathlib import Path

# %%
path = Path("E:\\CREWAI_APPLICATION_TRACKING_SYSTEM\\main.py").parent

# %%
folder = path / "Resume" / "logo.txt"

# %%
str(folder)

# %%
saved_folder = Path.mkdir(folder,parents=True,exist_ok=True)

# %%
import os

Path.cwd()
